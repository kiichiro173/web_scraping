# %%
import pandas as pd
from assets import models

from assets.database import db_session

# %%
df = pd.read_csv("./data.csv")

# %%
df.head()
# Out:
#         date  subscribers  reviews
# 0  2019/1/17         2671      194
# 1  2019/1/18         2671      195
# 2  2019/1/19         2674      197
# 3  2019/1/20         2685      199
# 4  2019/1/21         2695      199

# %%
df.iloc[0,0]
# Out:
# '2019/1/17'

# %%
import datetime

# %%
date = datetime.datetime.strptime(df.iloc[0,0], '%Y/%m/%d').date()
date
# Out:
# datetime.date(2019, 1, 17)

# %%
def read_data():
    from assets import models
    df = pd.read_csv("./data.csv")
    for index , _df in df.iterrows():
        #date型に変更
        date = datetime.datetime.strptime(_df['date'],'%Y/%m/%d').date()

        row = models.Data(date=date,subscribers=_df['subscribers'] , reviews=_df["reviews"])
        db_session.add(row)

    db_session.commit()
# Out:
# 2020-08-26 06:45:22,085 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-08-26 06:45:22,093 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-26 06:45:22,093 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-08-26 06:45:22,093 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-26 06:45:22,097 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-08-26 06:45:22,109 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,113 INFO sqlalchemy.engine.base.Engine ('2019-01-17', 2671, 194, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,131 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,135 INFO sqlalchemy.engine.base.Engine ('2019-01-18', 2671, 195, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,139 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,143 INFO sqlalchemy.engine.base.Engine ('2019-01-19', 2674, 197, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,147 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,147 INFO sqlalchemy.engine.base.Engine ('2019-01-20', 2685, 199, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,151 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,155 INFO sqlalchemy.engine.base.Engine ('2019-01-21', 2695, 199, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,159 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,163 INFO sqlalchemy.engine.base.Engine ('2019-01-22', 2701, 200, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,167 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,167 INFO sqlalchemy.engine.base.Engine ('2019-01-23', 2710, 200, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,171 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,175 INFO sqlalchemy.engine.base.Engine ('2019-01-24', 2718, 201, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,179 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,179 INFO sqlalchemy.engine.base.Engine ('2019-01-25', 2722, 201, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,183 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,187 INFO sqlalchemy.engine.base.Engine ('2019-01-26', 2725, 201, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,191 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,191 INFO sqlalchemy.engine.base.Engine ('2019-01-27', 2734, 202, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,195 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,199 INFO sqlalchemy.engine.base.Engine ('2019-01-28', 2753, 204, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,199 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,203 INFO sqlalchemy.engine.base.Engine ('2019-01-29', 2773, 206, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,207 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,207 INFO sqlalchemy.engine.base.Engine ('2019-01-30', 2785, 208, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,211 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,215 INFO sqlalchemy.engine.base.Engine ('2019-01-31', 2803, 210, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,215 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,219 INFO sqlalchemy.engine.base.Engine ('2019-02-01', 2845, 211, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,219 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,219 INFO sqlalchemy.engine.base.Engine ('2019-02-02', 2847, 213, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,223 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,223 INFO sqlalchemy.engine.base.Engine ('2019-02-03', 2847, 213, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,227 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,231 INFO sqlalchemy.engine.base.Engine ('2019-02-04', 2851, 217, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,232 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,236 INFO sqlalchemy.engine.base.Engine ('2019-02-05', 2852, 218, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,240 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,240 INFO sqlalchemy.engine.base.Engine ('2019-02-06', 2857, 219, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,244 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,244 INFO sqlalchemy.engine.base.Engine ('2019-02-07', 2861, 220, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,248 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,248 INFO sqlalchemy.engine.base.Engine ('2019-02-08', 2865, 222, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,252 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,252 INFO sqlalchemy.engine.base.Engine ('2019-02-09', 2870, 224, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,252 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,256 INFO sqlalchemy.engine.base.Engine ('2019-02-10', 2875, 224, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,260 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,264 INFO sqlalchemy.engine.base.Engine ('2019-02-11', 2892, 227, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,264 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,268 INFO sqlalchemy.engine.base.Engine ('2019-02-12', 2906, 229, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,272 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,272 INFO sqlalchemy.engine.base.Engine ('2019-02-13', 2919, 229, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,272 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,276 INFO sqlalchemy.engine.base.Engine ('2019-02-14', 2942, 231, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,276 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,280 INFO sqlalchemy.engine.base.Engine ('2019-02-15', 2974, 232, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,280 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,285 INFO sqlalchemy.engine.base.Engine ('2019-02-16', 2977, 234, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,285 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,288 INFO sqlalchemy.engine.base.Engine ('2019-02-17', 2978, 234, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,292 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,292 INFO sqlalchemy.engine.base.Engine ('2019-02-18', 2981, 234, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,296 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,301 INFO sqlalchemy.engine.base.Engine ('2019-02-19', 2983, 234, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,301 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,301 INFO sqlalchemy.engine.base.Engine ('2019-02-20', 2984, 237, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,305 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,305 INFO sqlalchemy.engine.base.Engine ('2019-02-21', 2987, 239, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,308 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,308 INFO sqlalchemy.engine.base.Engine ('2019-02-22', 2989, 239, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,313 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,313 INFO sqlalchemy.engine.base.Engine ('2019-02-23', 2993, 241, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,317 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,317 INFO sqlalchemy.engine.base.Engine ('2019-02-24', 2995, 241, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,321 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,321 INFO sqlalchemy.engine.base.Engine ('2019-02-25', 3009, 241, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,325 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,329 INFO sqlalchemy.engine.base.Engine ('2019-02-26', 3014, 243, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,329 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,333 INFO sqlalchemy.engine.base.Engine ('2019-02-27', 3023, 243, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,337 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,337 INFO sqlalchemy.engine.base.Engine ('2019-02-28', 3031, 243, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,337 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,341 INFO sqlalchemy.engine.base.Engine ('2019-03-01', 3052, 244, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,341 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,345 INFO sqlalchemy.engine.base.Engine ('2019-03-02', 3060, 245, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,345 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,349 INFO sqlalchemy.engine.base.Engine ('2019-03-03', 3062, 246, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,349 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,353 INFO sqlalchemy.engine.base.Engine ('2019-03-04', 3063, 249, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,353 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,357 INFO sqlalchemy.engine.base.Engine ('2019-03-05', 3066, 252, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,357 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,361 INFO sqlalchemy.engine.base.Engine ('2019-03-06', 3071, 254, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,365 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,365 INFO sqlalchemy.engine.base.Engine ('2019-03-07', 3074, 255, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,369 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,369 INFO sqlalchemy.engine.base.Engine ('2019-03-08', 3076, 256, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,369 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,373 INFO sqlalchemy.engine.base.Engine ('2019-03-09', 3077, 258, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,373 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,373 INFO sqlalchemy.engine.base.Engine ('2019-03-10', 3080, 258, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,373 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,377 INFO sqlalchemy.engine.base.Engine ('2019-03-11', 3087, 261, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,377 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,377 INFO sqlalchemy.engine.base.Engine ('2019-03-12', 3089, 261, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,381 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,381 INFO sqlalchemy.engine.base.Engine ('2019-03-13', 3093, 262, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,385 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,385 INFO sqlalchemy.engine.base.Engine ('2019-03-14', 3098, 262, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,389 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,393 INFO sqlalchemy.engine.base.Engine ('2019-03-15', 3104, 262, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,393 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,397 INFO sqlalchemy.engine.base.Engine ('2019-03-16', 3112, 262, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,401 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,401 INFO sqlalchemy.engine.base.Engine ('2019-03-17', 3120, 262, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,405 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,405 INFO sqlalchemy.engine.base.Engine ('2019-03-18', 3131, 265, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,405 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,409 INFO sqlalchemy.engine.base.Engine ('2019-03-19', 3142, 266, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,409 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,413 INFO sqlalchemy.engine.base.Engine ('2019-03-20', 3162, 266, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,413 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,417 INFO sqlalchemy.engine.base.Engine ('2019-03-21', 3173, 268, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,417 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,421 INFO sqlalchemy.engine.base.Engine ('2019-03-22', 3180, 269, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,421 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,425 INFO sqlalchemy.engine.base.Engine ('2019-03-23', 3187, 271, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,425 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,425 INFO sqlalchemy.engine.base.Engine ('2019-03-24', 3189, 271, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,429 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,433 INFO sqlalchemy.engine.base.Engine ('2019-03-25', 3196, 274, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,433 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,437 INFO sqlalchemy.engine.base.Engine ('2019-03-26', 3212, 274, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,441 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,441 INFO sqlalchemy.engine.base.Engine ('2019-03-27', 3220, 274, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,446 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,448 INFO sqlalchemy.engine.base.Engine ('2019-03-28', 3226, 275, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,451 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,452 INFO sqlalchemy.engine.base.Engine ('2019-03-29', 3241, 275, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,454 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,456 INFO sqlalchemy.engine.base.Engine ('2019-03-30', 3253, 278, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,456 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,460 INFO sqlalchemy.engine.base.Engine ('2019-03-31', 3255, 278, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,460 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,464 INFO sqlalchemy.engine.base.Engine ('2019-04-01', 3258, 280, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,464 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,464 INFO sqlalchemy.engine.base.Engine ('2019-04-02', 3262, 282, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,468 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,468 INFO sqlalchemy.engine.base.Engine ('2019-04-03', 3264, 282, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,472 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,472 INFO sqlalchemy.engine.base.Engine ('2019-04-04', 3272, 282, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,476 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,476 INFO sqlalchemy.engine.base.Engine ('2019-04-05', 3275, 284, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,480 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,480 INFO sqlalchemy.engine.base.Engine ('2019-04-06', 3276, 287, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,484 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,488 INFO sqlalchemy.engine.base.Engine ('2019-04-07', 3279, 289, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,488 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,492 INFO sqlalchemy.engine.base.Engine ('2019-04-08', 3285, 289, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,492 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,496 INFO sqlalchemy.engine.base.Engine ('2019-04-09', 3300, 291, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,500 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,500 INFO sqlalchemy.engine.base.Engine ('2019-04-10', 3306, 293, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,504 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,504 INFO sqlalchemy.engine.base.Engine ('2019-04-11', 3312, 295, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,508 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,508 INFO sqlalchemy.engine.base.Engine ('2019-04-12', 3319, 295, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,508 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,512 INFO sqlalchemy.engine.base.Engine ('2019-04-13', 3324, 295, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,512 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,516 INFO sqlalchemy.engine.base.Engine ('2019-04-14', 3325, 297, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,520 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,520 INFO sqlalchemy.engine.base.Engine ('2019-04-15', 3329, 298, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,524 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,524 INFO sqlalchemy.engine.base.Engine ('2019-04-16', 3331, 299, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,528 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,528 INFO sqlalchemy.engine.base.Engine ('2019-04-17', 3332, 299, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,532 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,532 INFO sqlalchemy.engine.base.Engine ('2019-04-18', 3333, 299, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,536 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,536 INFO sqlalchemy.engine.base.Engine ('2019-04-19', 3336, 299, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,540 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,540 INFO sqlalchemy.engine.base.Engine ('2019-04-20', 3339, 299, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,544 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,544 INFO sqlalchemy.engine.base.Engine ('2019-04-21', 3343, 300, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,548 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,548 INFO sqlalchemy.engine.base.Engine ('2019-04-22', 3349, 302, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,552 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,552 INFO sqlalchemy.engine.base.Engine ('2019-04-23', 3357, 303, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,556 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,556 INFO sqlalchemy.engine.base.Engine ('2019-04-24', 3370, 303, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,560 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,564 INFO sqlalchemy.engine.base.Engine ('2019-04-25', 3388, 304, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,564 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,564 INFO sqlalchemy.engine.base.Engine ('2019-04-26', 3412, 304, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,568 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,568 INFO sqlalchemy.engine.base.Engine ('2019-04-27', 3437, 305, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,572 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,572 INFO sqlalchemy.engine.base.Engine ('2019-04-28', 3439, 305, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,576 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,577 INFO sqlalchemy.engine.base.Engine ('2019-04-29', 3440, 308, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,581 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,581 INFO sqlalchemy.engine.base.Engine ('2019-04-30', 3447, 309, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,585 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,585 INFO sqlalchemy.engine.base.Engine ('2019-05-01', 3466, 310, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,589 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,589 INFO sqlalchemy.engine.base.Engine ('2019-05-02', 3481, 311, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,593 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,593 INFO sqlalchemy.engine.base.Engine ('2019-05-03', 3504, 314, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,597 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,597 INFO sqlalchemy.engine.base.Engine ('2019-05-04', 3522, 317, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,601 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,601 INFO sqlalchemy.engine.base.Engine ('2019-05-05', 3527, 322, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,601 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,605 INFO sqlalchemy.engine.base.Engine ('2019-05-06', 3533, 324, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,605 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,605 INFO sqlalchemy.engine.base.Engine ('2019-05-07', 3543, 327, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,609 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,613 INFO sqlalchemy.engine.base.Engine ('2019-05-08', 3546, 328, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,613 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,617 INFO sqlalchemy.engine.base.Engine ('2019-05-09', 3555, 330, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,617 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,621 INFO sqlalchemy.engine.base.Engine ('2019-05-10', 3566, 332, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,621 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,625 INFO sqlalchemy.engine.base.Engine ('2019-05-11', 3583, 334, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,625 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,629 INFO sqlalchemy.engine.base.Engine ('2019-05-12', 3594, 335, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,629 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,633 INFO sqlalchemy.engine.base.Engine ('2019-05-13', 3614, 338, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,633 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,633 INFO sqlalchemy.engine.base.Engine ('2019-05-14', 3633, 340, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,637 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,637 INFO sqlalchemy.engine.base.Engine ('2019-05-15', 3647, 344, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,641 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,641 INFO sqlalchemy.engine.base.Engine ('2019-05-16', 3648, 349, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,645 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,645 INFO sqlalchemy.engine.base.Engine ('2019-05-17', 3649, 349, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,645 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,649 INFO sqlalchemy.engine.base.Engine ('2019-05-18', 3651, 351, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,649 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,653 INFO sqlalchemy.engine.base.Engine ('2019-05-19', 3654, 351, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,657 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,657 INFO sqlalchemy.engine.base.Engine ('2019-05-20', 3658, 354, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,657 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,661 INFO sqlalchemy.engine.base.Engine ('2019-05-21', 3671, 354, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,665 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,665 INFO sqlalchemy.engine.base.Engine ('2019-05-22', 3675, 359, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,665 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,669 INFO sqlalchemy.engine.base.Engine ('2019-05-23', 3681, 359, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,669 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,669 INFO sqlalchemy.engine.base.Engine ('2019-05-24', 3694, 361, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,673 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,677 INFO sqlalchemy.engine.base.Engine ('2019-05-25', 3699, 361, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,677 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,681 INFO sqlalchemy.engine.base.Engine ('2019-05-26', 3711, 364, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,681 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,685 INFO sqlalchemy.engine.base.Engine ('2019-05-27', 3722, 368, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,685 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,689 INFO sqlalchemy.engine.base.Engine ('2019-05-28', 3734, 373, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,693 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,693 INFO sqlalchemy.engine.base.Engine ('2019-05-29', 3766, 374, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,693 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,697 INFO sqlalchemy.engine.base.Engine ('2019-05-30', 3781, 375, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,697 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,701 INFO sqlalchemy.engine.base.Engine ('2019-05-31', 3784, 375, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,701 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,705 INFO sqlalchemy.engine.base.Engine ('2019-06-01', 3789, 378, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,709 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,709 INFO sqlalchemy.engine.base.Engine ('2019-06-02', 3790, 379, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,713 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,713 INFO sqlalchemy.engine.base.Engine ('2019-06-03', 3793, 380, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,717 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,717 INFO sqlalchemy.engine.base.Engine ('2019-06-04', 3795, 383, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,721 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,721 INFO sqlalchemy.engine.base.Engine ('2019-06-05', 3808, 385, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,725 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,725 INFO sqlalchemy.engine.base.Engine ('2019-06-06', 3830, 386, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,729 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,733 INFO sqlalchemy.engine.base.Engine ('2019-06-07', 3843, 387, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,733 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,737 INFO sqlalchemy.engine.base.Engine ('2019-06-08', 3857, 390, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,737 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,741 INFO sqlalchemy.engine.base.Engine ('2019-06-09', 3870, 394, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,741 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,745 INFO sqlalchemy.engine.base.Engine ('2019-06-10', 3895, 395, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,749 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,749 INFO sqlalchemy.engine.base.Engine ('2019-06-11', 3919, 397, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,753 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,753 INFO sqlalchemy.engine.base.Engine ('2019-06-12', 3942, 399, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,757 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,757 INFO sqlalchemy.engine.base.Engine ('2019-06-13', 3983, 402, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,761 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,765 INFO sqlalchemy.engine.base.Engine ('2019-06-14', 4022, 404, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,765 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,765 INFO sqlalchemy.engine.base.Engine ('2019-06-15', 4053, 409, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,769 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,769 INFO sqlalchemy.engine.base.Engine ('2019-06-16', 4058, 410, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,773 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,773 INFO sqlalchemy.engine.base.Engine ('2019-06-17', 4063, 414, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,777 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,781 INFO sqlalchemy.engine.base.Engine ('2019-06-18', 4064, 417, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,785 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,785 INFO sqlalchemy.engine.base.Engine ('2019-06-19', 4065, 422, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,789 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,789 INFO sqlalchemy.engine.base.Engine ('2019-06-20', 4066, 424, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,793 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,797 INFO sqlalchemy.engine.base.Engine ('2019-06-21', 4069, 425, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,797 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,801 INFO sqlalchemy.engine.base.Engine ('2019-06-22', 4070, 426, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,801 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,805 INFO sqlalchemy.engine.base.Engine ('2019-06-23', 4073, 427, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,805 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,809 INFO sqlalchemy.engine.base.Engine ('2019-06-24', 4084, 427, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,813 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,813 INFO sqlalchemy.engine.base.Engine ('2019-06-25', 4108, 427, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,817 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,821 INFO sqlalchemy.engine.base.Engine ('2019-06-26', 4122, 433, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,821 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,825 INFO sqlalchemy.engine.base.Engine ('2019-06-27', 4132, 436, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,829 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,829 INFO sqlalchemy.engine.base.Engine ('2019-06-28', 4150, 440, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,833 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,833 INFO sqlalchemy.engine.base.Engine ('2019-06-29', 4162, 440, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,837 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,837 INFO sqlalchemy.engine.base.Engine ('2019-06-30', 4164, 446, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,841 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,841 INFO sqlalchemy.engine.base.Engine ('2019-07-01', 4167, 448, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,845 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,845 INFO sqlalchemy.engine.base.Engine ('2019-07-02', 4174, 450, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,849 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,853 INFO sqlalchemy.engine.base.Engine ('2019-07-03', 4179, 455, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,853 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,853 INFO sqlalchemy.engine.base.Engine ('2019-07-04', 4187, 456, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,857 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,861 INFO sqlalchemy.engine.base.Engine ('2019-07-05', 4200, 456, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,861 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,865 INFO sqlalchemy.engine.base.Engine ('2019-07-06', 4210, 458, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,865 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,869 INFO sqlalchemy.engine.base.Engine ('2019-07-07', 4211, 458, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,869 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,873 INFO sqlalchemy.engine.base.Engine ('2019-07-08', 4214, 464, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,873 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,877 INFO sqlalchemy.engine.base.Engine ('2019-07-09', 4219, 464, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,881 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,881 INFO sqlalchemy.engine.base.Engine ('2019-07-10', 4223, 468, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,885 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,885 INFO sqlalchemy.engine.base.Engine ('2019-07-11', 4228, 469, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,889 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,889 INFO sqlalchemy.engine.base.Engine ('2019-07-12', 4236, 469, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,893 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,893 INFO sqlalchemy.engine.base.Engine ('2019-07-13', 4239, 471, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,897 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,897 INFO sqlalchemy.engine.base.Engine ('2019-07-14', 4243, 471, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,901 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,901 INFO sqlalchemy.engine.base.Engine ('2019-07-15', 4250, 473, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,905 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,909 INFO sqlalchemy.engine.base.Engine ('2019-07-16', 4265, 476, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,909 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,913 INFO sqlalchemy.engine.base.Engine ('2019-07-17', 4288, 476, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,917 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,917 INFO sqlalchemy.engine.base.Engine ('2019-07-18', 4313, 483, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,921 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,921 INFO sqlalchemy.engine.base.Engine ('2019-07-19', 4329, 483, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,925 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,925 INFO sqlalchemy.engine.base.Engine ('2019-07-20', 4329, 486, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,929 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,929 INFO sqlalchemy.engine.base.Engine ('2019-07-21', 4329, 487, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,933 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,933 INFO sqlalchemy.engine.base.Engine ('2019-07-22', 4333, 492, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,937 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,937 INFO sqlalchemy.engine.base.Engine ('2019-07-23', 4335, 493, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:22,937 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:22,941 INFO sqlalchemy.engine.base.Engine ('2019-07-24', 4353, 494, '2020-08-26 06:45:17.772911')
# ...
# 2020-08-26 06:45:24,684 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,684 INFO sqlalchemy.engine.base.Engine ('2020-06-25', 8255, 1305, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,692 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,692 INFO sqlalchemy.engine.base.Engine ('2020-06-26', 8279, 1306, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,696 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,700 INFO sqlalchemy.engine.base.Engine ('2020-06-27', 8304, 1308, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,700 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,704 INFO sqlalchemy.engine.base.Engine ('2020-06-28', 8308, 1311, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,708 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,712 INFO sqlalchemy.engine.base.Engine ('2020-06-29', 8312, 1312, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,716 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,720 INFO sqlalchemy.engine.base.Engine ('2020-06-30', 8318, 1317, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,724 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,728 INFO sqlalchemy.engine.base.Engine ('2020-07-01', 8325, 1320, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,732 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,736 INFO sqlalchemy.engine.base.Engine ('2020-07-02', 8340, 1323, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,744 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,744 INFO sqlalchemy.engine.base.Engine ('2020-07-03', 8347, 1323, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,748 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,752 INFO sqlalchemy.engine.base.Engine ('2020-07-04', 8358, 1330, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,756 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,764 INFO sqlalchemy.engine.base.Engine ('2020-07-05', 8368, 1331, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,768 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,768 INFO sqlalchemy.engine.base.Engine ('2020-07-06', 8376, 1334, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,772 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,776 INFO sqlalchemy.engine.base.Engine ('2020-07-07', 8392, 1336, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,796 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,796 INFO sqlalchemy.engine.base.Engine ('2020-07-08', 8414, 1339, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,804 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,808 INFO sqlalchemy.engine.base.Engine ('2020-07-09', 8437, 1340, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,816 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,820 INFO sqlalchemy.engine.base.Engine ('2020-07-10', 8468, 1342, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,824 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,828 INFO sqlalchemy.engine.base.Engine ('2020-07-11', 8473, 1344, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,836 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,840 INFO sqlalchemy.engine.base.Engine ('2020-07-12', 8475, 1348, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,840 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,844 INFO sqlalchemy.engine.base.Engine ('2020-07-13', 8482, 1350, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,856 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,860 INFO sqlalchemy.engine.base.Engine ('2020-07-14', 8485, 1354, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,864 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,868 INFO sqlalchemy.engine.base.Engine ('2020-07-15', 8500, 1358, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,872 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,876 INFO sqlalchemy.engine.base.Engine ('2020-07-16', 8517, 1358, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,884 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,888 INFO sqlalchemy.engine.base.Engine ('2020-07-17', 8536, 1359, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,896 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,900 INFO sqlalchemy.engine.base.Engine ('2020-07-18', 8539, 1359, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,900 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,904 INFO sqlalchemy.engine.base.Engine ('2020-07-19', 8540, 1363, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,908 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,916 INFO sqlalchemy.engine.base.Engine ('2020-07-20', 8545, 1363, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,924 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,932 INFO sqlalchemy.engine.base.Engine ('2020-07-21', 8551, 1365, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,936 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,936 INFO sqlalchemy.engine.base.Engine ('2020-07-22', 8553, 1369, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,944 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,948 INFO sqlalchemy.engine.base.Engine ('2020-07-23', 8556, 1371, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,952 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,956 INFO sqlalchemy.engine.base.Engine ('2020-07-24', 8564, 1374, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,964 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,968 INFO sqlalchemy.engine.base.Engine ('2020-07-25', 8572, 1376, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,972 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,976 INFO sqlalchemy.engine.base.Engine ('2020-07-26', 8574, 1382, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,988 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,988 INFO sqlalchemy.engine.base.Engine ('2020-07-27', 8583, 1386, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:24,992 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:24,996 INFO sqlalchemy.engine.base.Engine ('2020-07-28', 8601, 1389, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:25,000 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:25,004 INFO sqlalchemy.engine.base.Engine ('2020-07-29', 8614, 1391, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:25,008 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:25,008 INFO sqlalchemy.engine.base.Engine ('2020-07-30', 8625, 1393, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:25,016 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:25,020 INFO sqlalchemy.engine.base.Engine ('2020-07-31', 8642, 1394, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:25,024 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:25,028 INFO sqlalchemy.engine.base.Engine ('2020-08-01', 8657, 1394, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:25,032 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:25,036 INFO sqlalchemy.engine.base.Engine ('2020-08-02', 8662, 1396, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:25,040 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:25,044 INFO sqlalchemy.engine.base.Engine ('2020-08-03', 8665, 1399, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:25,048 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:25,052 INFO sqlalchemy.engine.base.Engine ('2020-08-04', 8669, 1402, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:25,056 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:25,060 INFO sqlalchemy.engine.base.Engine ('2020-08-05', 8671, 1403, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:25,064 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:25,068 INFO sqlalchemy.engine.base.Engine ('2020-08-06', 8680, 1403, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:25,072 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:25,076 INFO sqlalchemy.engine.base.Engine ('2020-08-07', 8690, 1403, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:25,080 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:25,088 INFO sqlalchemy.engine.base.Engine ('2020-08-08', 8694, 1404, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:25,092 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:25,096 INFO sqlalchemy.engine.base.Engine ('2020-08-09', 8696, 1405, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:25,100 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:25,104 INFO sqlalchemy.engine.base.Engine ('2020-08-10', 8697, 1408, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:25,108 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:25,112 INFO sqlalchemy.engine.base.Engine ('2020-08-11', 8704, 1409, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:25,116 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:25,120 INFO sqlalchemy.engine.base.Engine ('2020-08-12', 8705, 1411, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:25,124 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:25,128 INFO sqlalchemy.engine.base.Engine ('2020-08-13', 8707, 1416, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:25,132 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:25,136 INFO sqlalchemy.engine.base.Engine ('2020-08-14', 8710, 1420, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:25,140 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:25,140 INFO sqlalchemy.engine.base.Engine ('2020-08-15', 8714, 1420, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:25,144 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:25,148 INFO sqlalchemy.engine.base.Engine ('2020-08-16', 8723, 1420, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:25,156 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:25,164 INFO sqlalchemy.engine.base.Engine ('2020-08-17', 8725, 1421, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:25,168 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:25,172 INFO sqlalchemy.engine.base.Engine ('2020-08-18', 8731, 1421, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:25,176 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:25,180 INFO sqlalchemy.engine.base.Engine ('2020-08-19', 8749, 1424, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:25,183 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:25,184 INFO sqlalchemy.engine.base.Engine ('2020-08-20', 8767, 1424, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:25,188 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:25,192 INFO sqlalchemy.engine.base.Engine ('2020-08-21', 8784, 1426, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:25,196 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:25,200 INFO sqlalchemy.engine.base.Engine ('2020-08-22', 8793, 1426, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:25,204 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:25,204 INFO sqlalchemy.engine.base.Engine ('2020-08-23', 8808, 1426, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:25,212 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:25,216 INFO sqlalchemy.engine.base.Engine ('2020-08-24', 8825, 1429, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:25,220 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:25,220 INFO sqlalchemy.engine.base.Engine ('2020-08-25', 8836, 1443, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:25,228 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-08-26 06:45:25,232 INFO sqlalchemy.engine.base.Engine ('2020-08-26', 8836, 1443, '2020-08-26 06:45:17.772911')
# 2020-08-26 06:45:25,264 INFO sqlalchemy.engine.base.Engine COMMIT
