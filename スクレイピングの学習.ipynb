# %%
import requests 
from bs4 import BeautifulSoup

#load_url = "https://scraping-for-beginner.herokuapp.com/image"
#html = requests.get(load_url)
#soup = BeautifulSoup(html.content , 'html.parser')#html.contentのデータを解析してsoupに渡している

#print(soup)
#スクレイピングしたいURL
url = "https://scraping-for-beginner.herokuapp.com/ranking/"
html = requests.get(url)
html_data = BeautifulSoup(html.content , 'html.parser')#html.contentのデータを解析してhtml_dataに渡している
print(html_data)
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Webスクレイピング入門者のためのサイト</title>
# <!-- Compiled and minified CSS -->
# <link href="https://cdnjs.cloudflare.com/ajax/libs/materialize/1.0.0-rc.2/css/materialize.min.css" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
#
#   <!-- <link rel="stylesheet" href="static/assets/css/style.css">
#   <link rel="stylesheet" href="static/assets/css/image.css">
#   <link rel="stylesheet" href="static/assets/css/ranking.css"> -->
# <link href="/static/assets/css/style.css" rel="stylesheet"/>
# <link href="/static/assets/css/image.css" rel="stylesheet"/>
# <link href="/static/assets/css/ranking.css" rel="stylesheet"/>
# </head>
# <body>
# <!-- Navbar -->
# <div class="navbar-fixed">
# <!-- Dropdown Structure -->
# <nav class="">
# <div class="nav-wrapper row">
# <div class="col s5 l4 offset-s1 offset-l1">
# /">Webスクレイピング入門</a>
# </div>
# ...

# %%
#soup.find("タグ名")で指定した要素を一つ見つけて取り出す
html_data.find("li")
# Out:
# /login_page">ログイン</a></li>

# %%
#html_data.find("タグ名").textでテキストだけ取得することができる
html_data.find("li").text
# Out:
# 'ログイン'

# %%
#html_data.find_all("タグ名")で指定した要素をすべて見つけて取り出す
html_data.find_all("li")
# Out:
# /login_page">ログイン</a></li>,
#  <li><a class="" href="/ranking/">ランキング</a></li>,
#  <li><a class="" href="/image">画像</a></li>,
#  <li><a class="" href="/udemy">Udemy</a></li>,
#  <li><a class="" href="https://scraping-for-beginner.readthedocs.io/" target="”_blank”">サンプルコード</a></li>,
#  <li class="disabled"><a href="/ranking/?page=prev"><i class="material-icons">chevron_left</i></a></li>,
#  <li class="active"><a href="/ranking/?page=1">1</a></li>,
#  <li class="waves-effect"><a href="/ranking/?page=2">2</a></li>,
#  <li class="waves-effect"><a href="/ranking/?page=3">3</a></li>,
#  <li class="waves-effect"><a href="/ranking/?page=next"><i class="material-icons">chevron_right</i></a></li>]

# %%
#テキストのみをすべて取得したい場合はfor文を使用する
for elements in html_data.find_all("li"):
    print(elements.text)
# Out:
# ログイン
# ランキング
# 画像
# Udemy
# サンプルコード
# chevron_left
# 1
# 2
# 3
# chevron_right

# %%
#classやidを指定して検索することも可能
active = html_data.find(class_ = "active")
active
# Out:
# <li class="active"><a href="/ranking/?page=1">1</a></li>

# %%
#activeのliのみ抽出
active.find_all("li")
# Out:
# []

# %%
#chap2のliのテキストを取得
for chap2_li in chap2.find_all("li"):
    print(chap2_li.text)
# Out:
# HTMLを解析してみよう
# ニュースの最新記事一覧を取得してみよう
# リンク一覧をファイルに書き出そう
# 画像を一括ダウンロードしよう

# %%
import requests

image_url = "https://www.ymori.com/books/python2nen/sample1.png"
imgdata = requests.get(image_url)

filename = image_url.split('/')[-1]

with open(filename,mode = 'wb') as f:# mode = wbで画像ファイルであることを指定している
    f.write(imgdata.content)

# %%
import requests 
from pathlib import Path

#保存用のフォルダを作成している
out_folder = Path("image_download")
out_folder.mkdir(exist_ok = True)

image_url = "https://www.ymori.com/books/python2nen/sample1.png"
imgdata = requests.get(image_url)

filename = image_url.split('/')[-1]
out_path = out_folder.joinpath(filename)

with open(out_path , mode = 'wb') as f:# mode = wbで画像ファイルであることを指定している
    f.write(imgdata.content)

# %%
import requests
from bs4 import BeautifulSoup
import urllib

load_url = "https://www.ymori.com/books/python2nen/test2.html"
html = requests.get(load_url)
soup = BeautifulSoup(html.content,"html.parser")

for element in soup.find_all("img"):
    src = element.get("src")
    print(src)
    image_url = urllib.parse.urljoin(load_url,src)
    filename = image_url.split("/")[-1]
    print(image_url , ">>" , filename)
    print()
# Out:
# https://www.ymori.com/books/python2nen/sample1.png
# https://www.ymori.com/books/python2nen/sample1.png >> sample1.png
#
# ./sample2.png
# https://www.ymori.com/books/python2nen/sample2.png >> sample2.png
#
# ./sample3.png
# https://www.ymori.com/books/python2nen/sample3.png >> sample3.png

# %%
import requests
from bs4 import BeautifulSoup
import urllib
import pandas as pd

train = pd.read_csv("C:\Users\solud\OneDrive\デスクトップ\ラクスパートナーズ\kaggle\Youtube_Prediction/train_data.csv")
train.head()
# Out:
#   File "<ipython-input-1-41bd0284ca4b>", line 6
#     train = pd.read_csv("C:\Users\solud\OneDrive\デスクトップ\ラクスパートナーズ\kaggle\Youtube_Prediction/train_data.csv")
#                        ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
#ページにある画像をすべて持ってくる
import requests
from bs4 import BeautifulSoup
from pathlib import Path
import urllib
import time

#webページを取得
load_url =  "https://www.ymori.com/books/python2nen/test2.html"
html = requests.get(load_url)
soup = BeautifulSoup(html.content , "html.parser")#htmlファイルを取得している


#保存するフォルダを作成
out_folder = Path("download2")
out_folder.mkdir(exist_ok = True)

#すべてのimgタグを検索しリンクを取得
for element in soup.find_all("img"):
    #imgタグの中のsrc=の部分を取得
    src = element.get('src')
    
    #絶対URLを使用し画像データを取得する
    image_url = urllib.parse.urljoin(load_url , src)#画像の保存されているURLを取得している
    imgdata = requests.get(image_url)#画像のデータを取得してる
    
    #urlから画像ファイル名取り出してフォルダ名とつなげる
    filename = image_url.split('/')[-1]
    out_path = out_folder.joinpath(filename)#保存先のパスを求めている（download2\sample1.pngこんな感じ）
    
    #画像データをファイルに書き出す
# Out:
#   File "<ipython-input-2-1c0a03ac5d64>", line 32
#     with open(out_path , mode = "wb") as
#                                         ^
# SyntaxError: invalid syntax

# %%
import folium 
m = folium.Map(location=[35.94297,136.198863] , zoom_start = 16)
m.save("sabae.html")
